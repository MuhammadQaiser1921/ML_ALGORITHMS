# %% [markdown]
# <a href="https://colab.research.google.com/github/MuhammadQaiser1921/ML_ALGORITHMS/blob/main/Polynomial_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot  as plt
import seaborn as sns

# %%
dataset = pd.read_csv('/content/sample_data/polynomial_regression_data.csv')

# %%
dataset.head(5)
# Out:
#    Level  Salary
# 0      1    1206
# 1      2    1041
# 2      3    1541
# 3      4    1274
# 4      5    1063

# %%
plt.scatter(dataset["Level"],dataset["Salary"])
plt.show()

# %%
dataset.corr()
# Out:
#            Level    Salary
# Level   1.000000  0.974079
# Salary  0.974079  1.000000

# %%
x = dataset[['Level']]
y= dataset['Salary']

# %%
from sklearn.preprocessing import PolynomialFeatures
pf = PolynomialFeatures(degree=3)
pf.fit(x)
x = pf.transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_train,y_train)*100
# Out:
# 99.97425451312986

# %%
lr.predict(x_test)
# Out:
# array([40549.64586882, 18358.52298889, 29868.10290679, 13924.96966307,
#        13415.56951534, 11018.90818518,  4765.50472384, 37942.03012154,
#         2143.73194555,  1113.00419992,  3725.12096691,  7340.96037503,
#        32189.91705746,  8475.59605922, 46963.49924901,  1398.34001521,
#        34597.93339395, 35419.6931464 ,  2476.36374212,  7708.98352578])

# %%
plt.scatter(dataset["Level"],dataset["Salary"])
plt.plot(dataset["Level"],lr.predict(x),c='red')
plt.show()

# %%
#y = m1x1 + m2x2^2 + m3x3^3 + c

# %%
lr.coef_
# Out:
# array([ 0.00000000e+00,  3.94216877e+01,  5.33133264e+00, -2.44289333e-03])

# %%
lr.intercept_
# Out:
# 1068.2536225235563
